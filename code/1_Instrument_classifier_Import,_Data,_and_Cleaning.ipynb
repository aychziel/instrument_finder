# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import os
import re
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import models, layers
from IPython.display import Audio
from keras.utils import to_categorical
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Some of these imports are audio specific imports such as librosa and librosa.display which help read audio data, trim, create spectograsm etc.
#
# "from IPython.display import Audio" allows playing audio signals directly in python enviroments.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#ls /content/drive/MyDrive/

# %% [markdown]
# # Dataset
#
#  ### Background on data: The following data includes 2065 audio samples ( Kicks, Snares, 808's, Open hats, and Closed hats) from my own music production library which is made from several sources which include but are not limited to music production/sample sharing websites such as Landr, Splice, Reddit etc. The audio library can be accessed [Here](https://drive.google.com/drive/folders/1Dl2wvDMLQip063K0ncE7Anv7zzn25a0L?usp=sharing). Some of the sounds also came from the [drum classifier github project](https://github.com/aabalke33/drum-audio-classifier/tree/main). These audio samples are typically a few seconds (0-4 seconds) in WAV File formats. I am looking to explore how to convert these samples into their own features which include arrays of time, pitch, and amplitude to train the mode to accuratley classify the instruments based on any given audio sample in this library or outside of this library. Before starting to work with data, I decided to review the unique audio files to ensure data integrity and assumption made as far as the beginning stage. This will be explored further in the cleaning section.
# ---
# ### Data Dictionary ###
#
#
# | Feature | Type | Dataset | Description |
# |---------|------|---------|-------------|
# |**File_path**|*str*| My data | The file path or directory where the audio file is located.|
# |**File_name**|*str*| My data | The name of the file, including the file extension. |
# |**Instrument**|*str*| My data | The name of the instrument. Instruments are: Kick, Snare, 808, Open hat, Closed hat|
# |**End_time**|*datetime*| My data | The timeframe in seconds that the audio sample ends |
# |**Index**|*int*| My data | An index value assigned for instrument based on the instrument column. |
# |**Instrument_encoded**|*int*| My data | An encoded value representing the instrument type. |
# |**Instrument_0**|*int*| My data | A binary indicator (0 or 1), representing whether the sample is a Kick drum or not.|
# |**Instrument_1**|*int*| My data | A binary indicator (0 or 1), representing whether the sample is a Snare drum or not. |
# |**Instrument_2**|*int*| My data | A binary indicator (0 or 1),representing whether the sample is an 808 drum or not. |
# |**Instrument_3**|*int*| My data | A binary indicator (0 or 1), representing whether the sample is an Open hat or not. |
# |**Instrument_4**|*int*| My data | A binary indicator (0 or 1), representing whether the sample is a Closed hat or not. |
#
#
# ---
#
# To start, I want to create a dataframe that has the following columns: File_path, File_name, Instrument, Start_time and End_time. While I have
# thought about labeling this a "drum classfier" meaning that my column would have technically been "Drums", I decided to keep it general to instrument because I am intrested in exploring this model in the future with various intruments.
#
# I may assign variable where I drop some of these columns later in the process but for organizational purposes, I am intrested in making this my main df and saving it as such.

# %%
# Set the absolute path to the 'Drums' folder
abs_path = '/content/drive/MyDrive/Drums/'

all_files = os.listdir(abs_path)

# Create a list of full file paths
file_paths = [os.path.join(abs_path, f) for f in all_files]

df = pd.DataFrame({'File_path': file_paths})

# Extract the filenames from the file paths and instrument types
df['File_name'] = df['File_path'].apply(lambda x: os.path.basename(x).split('.')[0])

df['Instrument'] = df['File_name'].apply(lambda x: x.split()[0])

# %% [markdown]
# Now that I created the dataframe by assigning paths and lists, I want to create the Instrument column which would have all the diffrent types of instruments which in this case will be 5 diffrent instruments: Kick, Snare, Open Hat, Closed Hat and 808 to label my drum sounds accordingly. I also want to be sure that I am able to get all the diffrent combination of file names as there are many files that are labled diffrently than just their name in each category. This function will help sort through the diffrent names of each instrument.

# %%
instrument_mapping = {
    'kick': 'Kick',
    'snare': 'Snare',
    '808': '808',
}
def extract_instrument(file_path, instrument_str=None):
    # Extract the filename from the file path
    filename = os.path.basename(file_path)

    pattern = r'(kick|snare|closedhat|closed-hat|closed-hi-hat|openhat|open hat|OH|Oh|open\shat\s\d+|\(open\shat\)|\d+\s-\sOH|808|HH|OPEN-HAT)(_\d+)?'
    match = re.search(pattern, filename, re.IGNORECASE)

    if match:
        instrument = match.group(1).lower()
        if instrument in ['closedhat', 'closed-hat', 'closed-hi-hat']:
            return 'Closed Hat'
        elif instrument in ['openhat', 'open hat', 'OH', 'oh', 'Oh', 'OPEN-HAT', 'HH', 'Hh']:
            return 'Open Hat'
        else:
            return instrument_mapping.get(instrument, instrument.replace('-', ' ').capitalize())
    elif instrument_str:
        # Extract the instrument name from the 'Instrument' column
        match = re.search(r'(kick|snare|closedhat|closed-hat|closed-hi-hat|openhat|open hat|OH|Oh|open\shat\s\d+|\(open\shat\)|HH|OPEN-HAT)', instrument_str, re.IGNORECASE)
        if match:
            instrument = match.group(1).lower()
            if instrument in ['closedhat', 'closed-hat', 'closed-hi-hat']:
                return 'Closed Hat'
            elif instrument in ['openhat', 'open hat', 'OH', 'oh', 'Oh', 'OPEN-HAT', 'HH', 'Hh']:
                return 'Open Hat'
            else:
                return instrument_mapping.get(instrument, instrument.replace('-', ' ').capitalize())

    return 'NaN'

# Apply the extract_instrument function to the 'File_path' and 'Instrument' columns
df['Instrument'] = df.apply(lambda row: extract_instrument(row['File_path'], row.get('Instrument')), axis=1)

# %%
# Extract audio start to finish
df['Start_time'] = 0  # Initialize start time to 0
df['End_time'] = 0

for index, row in df.iterrows():
    audio, sr = librosa.load(row['File_path'])
    duration = librosa.get_duration(y=audio, sr=sr)
    df.at[index, 'End_time'] = duration

# %% [markdown]
# I am extracting the audio data using librosa. This create will creat the start time and end time columns.

# %%
df.head(2000)
# Out:
#                                               File_path  \
# 0     /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1     /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2     /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3     /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4     /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
# ...                                                 ...
# 1995  /content/drive/MyDrive/Drums/Kick 35 (Roy Ayer...
# 1996  /content/drive/MyDrive/Drums/Open hat 15 (Roy ...
# 1997  /content/drive/MyDrive/Drums/Snare 38 (Roy Aye...
# 1998  /content/drive/MyDrive/Drums/Kick 36 (Roy Ayer...
# 1999  /content/drive/MyDrive/Drums/Snare 39 (Roy Aye...
#
#                                               File_name Instrument  \
# 0     Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...      Snare
# 1     Snare 41 (Roy Ayers - The Old One Two (Move To...      Snare
# 2     Snare 42 (Roy Ayers - No Question (Album Versi...      Snare
# 3                Kick 37 (Roy Ayers - Can't You See Me)       Kick
# 4                Kick 38 (Roy Ayers - Can't You See Me)       Kick
# ...                                                 ...        ...
# 1995  Kick 35 (Roy Ayers - Show Us A Feeling (Album ...       Kick
# 1996  Open hat 15 (Roy Ayers - Show Us A Feeling (Al...   Open Hat
# 1997                  Snare 38 (Roy Ayers - 2000 Black)      Snare
# 1998               Kick 36 (Roy Ayers - Time And Space)       Kick
# 1999              Snare 39 (Roy Ayers - Time And Space)      Snare
#
#       Start_time  End_time
# 0              0  0.100136
# 1              0  0.154694
# 2              0  0.189342
# 3              0  0.417596
# 4              0  0.258730
# ...          ...       ...
# 1995           0  0.210794
# 1996           0  0.360272
# 1997           0  0.140454
# 1998           0  0.322948
# 1999           0  0.348299
#
# [2000 rows x 5 columns]

# %% [markdown]
# # Cleaning process.

# %% [markdown]
#   Now that I created the dataframe, I am intrested in cleaning up some of the data such as checking for missing data, nulls.
#
#   Note: The instruments that need to be included in the instrument column are Snare, Kick, Open Hat, 808 and Closed Hat.

# %%
df.shape
# Out:
# (2068, 5)

# %% [markdown]
# As of now, there are 2068 rows and 5 columns

# %%
df.head(20)
# Out:
#                                             File_path  \
# 0   /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1   /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2   /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3   /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4   /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
# 5   /content/drive/MyDrive/Drums/Snare 43 (Roy Aye...
# 6   /content/drive/MyDrive/Drums/Open hat 16 (Roy ...
# 7   /content/drive/MyDrive/Drums/Snare 44 (Roy Aye...
# 8   /content/drive/MyDrive/Drums/Snare 45 (Roy Aye...
# 9   /content/drive/MyDrive/Drums/Snare 46 (Roy Aye...
# 10  /content/drive/MyDrive/Drums/Snare 47 (Roy Aye...
# 11  /content/drive/MyDrive/Drums/Snare 48 (Bob Jam...
# 12  /content/drive/MyDrive/Drums/Open hat 17 (Bob ...
# 13  /content/drive/MyDrive/Drums/Snare 49 (brushed...
# 14         /content/drive/MyDrive/Drums/808 - Ice.wav
# 15  /content/drive/MyDrive/Drums/808 - Frosted Fla...
# 16          /content/drive/MyDrive/Drums/808 - 5K.wav
# 17       /content/drive/MyDrive/Drums/808 - Piano.wav
# 18       /content/drive/MyDrive/Drums/808 - Ghost.wav
# 19     /content/drive/MyDrive/Drums/Kick - Secret.wav
#
#                                             File_name Instrument  Start_time  \
# 0   Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...      Snare           0
# 1   Snare 41 (Roy Ayers - The Old One Two (Move To...      Snare           0
# 2   Snare 42 (Roy Ayers - No Question (Album Versi...      Snare           0
# 3              Kick 37 (Roy Ayers - Can't You See Me)       Kick           0
# 4              Kick 38 (Roy Ayers - Can't You See Me)       Kick           0
# 5   Snare 43 (Roy Ayers - Everytime I See You (Alb...      Snare           0
# 6   Open hat 16 (Roy Ayers - Everytime I See You (...   Open Hat           0
# 7   Snare 44 (Roy Ayers - Everytime I See You (Alb...      Snare           0
# 8   Snare 45 (Roy Ayers - Everytime I See You (Alb...      Snare           0
# 9   Snare 46 (Roy Ayers - Everytime I See You (Alb...      Snare           0
# 10  Snare 47 (Roy Ayers - It Ain't Your Sign It's ...      Snare           0
# 11   Snare 48 (Bob James - Take Me To The Mardi Gras)      Snare           0
# 12      Open hat 17 (Bob James - Brighton By The Sea)   Open Hat           0
# 13   Snare 49 (brushed) (Bob James - We're All Alone)      Snare           0
# 14                                          808 - Ice        808           0
# 15                               808 - Frosted Flakes        808           0
# 16                                           808 - 5K        808           0
# 17                                        808 - Piano        808           0
# 18                                        808 - Ghost        808           0
# 19                                      Kick - Secret       Kick           0
#
#     End_time
# 0   0.100136
# 1   0.154694
# 2   0.189342
# 3   0.417596
# 4   0.258730
# 5   0.164082
# 6   0.662268
# 7   0.342222
# 8   0.332381
# 9   0.161224
# 10  0.416281
# 11  0.292789
# 12  0.935692
# 13  0.323583
# 14  1.957551
# 15  2.483946
# 16  4.179501
# 17  2.412336
# 18  2.610068
# 19  0.212290

# %% [markdown]
# I noticed that there are a few things that I need to clean which include making sure the Instruments in the "Instruments" Column are labled accordingly. I would like to make sure that this column is especially cleaned because I want to make sure that I am able to create an Index for each  instrument.

# %% [markdown]
# I want to start off by checking the dataframe for nulls, duplicates, abnormalities etc.

# %%
df.isnull().sum()
# Out:
# File_path     0
# File_name     0
# Instrument    0
# Start_time    0
# End_time      0
# dtype: int64

# %%
null_indices = df[df['Instrument'].isnull()].index
if len(null_indices) > 0:
    null_rows = df.loc[null_indices]
else:
    print("There are no null values in the 'Instrument' column.")
# Out:
# There are no null values in the 'Instrument' column.

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2063    False
# 2064    False
# 2065    False
# 2066    False
# 2067    False
# Length: 2068, dtype: bool

# %%
df.dtypes
# Out:
# File_path      object
# File_name      object
# Instrument     object
# Start_time      int64
# End_time      float64
# dtype: object

# %%
hh_values = df[df['Instrument'].str.contains('Hh', case=False)]
hh_values
# Out:
#                                               File_path       File_name  \
# 1005  /content/drive/MyDrive/Drums/730! HH (20)🛰🥤.wa...  730! HH (20)🛰🥤
# 1018  /content/drive/MyDrive/Drums/730! HH (37)🛰🥤.wa...  730! HH (37)🛰🥤
# 1023  /content/drive/MyDrive/Drums/730! HH (11)🛰🥤.wa...  730! HH (11)🛰🥤
# 1026  /content/drive/MyDrive/Drums/730! HH (21)🛰🥤.wa...  730! HH (21)🛰🥤
# 1032  /content/drive/MyDrive/Drums/730! HH (26)🛰🥤.wa...  730! HH (26)🛰🥤
# 1035  /content/drive/MyDrive/Drums/730! HH (14)🛰🥤.wa...  730! HH (14)🛰🥤
# 1037  /content/drive/MyDrive/Drums/730! HH (40)🛰🥤.wa...  730! HH (40)🛰🥤
# 1042  /content/drive/MyDrive/Drums/730! HH (36)🛰🥤.wa...  730! HH (36)🛰🥤
# 1056  /content/drive/MyDrive/Drums/730! HH (46)🛰🥤.wa...  730! HH (46)🛰🥤
# 1057  /content/drive/MyDrive/Drums/730! HH (6)🛰🥤.wav...   730! HH (6)🛰🥤
# 1061  /content/drive/MyDrive/Drums/730! HH (7)🛰🥤.wav...   730! HH (7)🛰🥤
# 1064  /content/drive/MyDrive/Drums/730! HH (27)🛰🥤.wa...  730! HH (27)🛰🥤
# 1081  /content/drive/MyDrive/Drums/730! HH (8)🛰🥤.wav...   730! HH (8)🛰🥤
# 1086  /content/drive/MyDrive/Drums/730! HH (15)🛰🥤.wa...  730! HH (15)🛰🥤
# 1092  /content/drive/MyDrive/Drums/730! HH (48)🛰🥤.wa...  730! HH (48)🛰🥤
# 1101  /content/drive/MyDrive/Drums/730! HH (42)🛰🥤.wa...  730! HH (42)🛰🥤
# 1102  /content/drive/MyDrive/Drums/730! HH (39)🛰🥤.wa...  730! HH (39)🛰🥤
# 1107  /content/drive/MyDrive/Drums/730! HH (13)🛰🥤.wa...  730! HH (13)🛰🥤
# 1123  /content/drive/MyDrive/Drums/730! HH (28)🛰🥤.wa...  730! HH (28)🛰🥤
# 1133  /content/drive/MyDrive/Drums/730! HH (30)🛰🥤.wa...  730! HH (30)🛰🥤
# 1137  /content/drive/MyDrive/Drums/730! HH (32)🛰🥤.wa...  730! HH (32)🛰🥤
# 1148  /content/drive/MyDrive/Drums/730! HH (25)🛰🥤.wa...  730! HH (25)🛰🥤
# 1154  /content/drive/MyDrive/Drums/730! HH (45)🛰🥤.wa...  730! HH (45)🛰🥤
# 1196  /content/drive/MyDrive/Drums/730! HH (23)🛰🥤.wa...  730! HH (23)🛰🥤
# 1229  /content/drive/MyDrive/Drums/730! HH (31)🛰🥤.wa...  730! HH (31)🛰🥤
# 1234  /content/drive/MyDrive/Drums/730! HH (12)🛰🥤.wa...  730! HH (12)🛰🥤
# 1238  /content/drive/MyDrive/Drums/730! HH (35)🛰🥤.wa...  730! HH (35)🛰🥤
# 1254  /content/drive/MyDrive/Drums/730! HH (38)🛰🥤.wa...  730! HH (38)🛰🥤
# 1261  /content/drive/MyDrive/Drums/730! HH (1)🛰🥤.wav...   730! HH (1)🛰🥤
# 1267  /content/drive/MyDrive/Drums/730! HH (43)🛰🥤.wa...  730! HH (43)🛰🥤
# 1289  /content/drive/MyDrive/Drums/730! HH (2)🛰🥤.wav...   730! HH (2)🛰🥤
# 1295  /content/drive/MyDrive/Drums/730! HH (3)🛰🥤.wav...   730! HH (3)🛰🥤
# 1303  /content/drive/MyDrive/Drums/730! HH (24)🛰🥤.wa...  730! HH (24)🛰🥤
# 1315  /content/drive/MyDrive/Drums/730! HH (18)🛰🥤.wa...  730! HH (18)🛰🥤
# 1366  /content/drive/MyDrive/Drums/730! HH (41)🛰🥤.wa...  730! HH (41)🛰🥤
# 1367  /content/drive/MyDrive/Drums/730! HH (34)🛰🥤.wa...  730! HH (34)🛰🥤
# 1379  /content/drive/MyDrive/Drums/730! HH (50)🛰🥤.wa...  730! HH (50)🛰🥤
# 1382  /content/drive/MyDrive/Drums/730! HH (49)🛰🥤.wa...  730! HH (49)🛰🥤
# 1385  /content/drive/MyDrive/Drums/730! HH (33)🛰🥤.wa...  730! HH (33)🛰🥤
# 1394  /content/drive/MyDrive/Drums/730! HH (9)🛰🥤.wav...   730! HH (9)🛰🥤
# 1402  /content/drive/MyDrive/Drums/730! HH (29)🛰🥤.wa...  730! HH (29)🛰🥤
# 1415  /content/drive/MyDrive/Drums/730! HH (47)🛰🥤.wa...  730! HH (47)🛰🥤
# 1426  /content/drive/MyDrive/Drums/730! HH (16)🛰🥤.wa...  730! HH (16)🛰🥤
# 1439  /content/drive/MyDrive/Drums/730! HH (22)🛰🥤.wa...  730! HH (22)🛰🥤
# 1463  /content/drive/MyDrive/Drums/730! HH (5)🛰🥤.wav...   730! HH (5)🛰🥤
# 1488  /content/drive/MyDrive/Drums/730! HH (44)🛰🥤.wa...  730! HH (44)🛰🥤
# 1500  /content/drive/MyDrive/Drums/730! HH (17)🛰🥤.wa...  730! HH (17)🛰🥤
# 2006  /content/drive/MyDrive/Drums/730! HH (10)🛰🥤.wa...  730! HH (10)🛰🥤
# 2044  /content/drive/MyDrive/Drums/730! HH (4)🛰🥤.wav...   730! HH (4)🛰🥤
# 2045  /content/drive/MyDrive/Drums/730! HH (19)🛰🥤.wa...  730! HH (19)🛰🥤
#
#      Instrument  Start_time  End_time
# 1005         Hh           0  0.760317
# 1018         Hh           0  0.760317
# 1023         Hh           0  0.500000
# 1026         Hh           0  0.760317
# 1032         Hh           0  0.760317
# 1035         Hh           0  0.212018
# 1037         Hh           0  0.760317
# 1042         Hh           0  0.760317
# 1056         Hh           0  0.069796
# 1057         Hh           0  0.062540
# 1061         Hh           0  0.037596
# 1064         Hh           0  0.760317
# 1081         Hh           0  0.119093
# 1086         Hh           0  0.032698
# 1092         Hh           0  0.330204
# 1101         Hh           0  0.760317
# 1102         Hh           0  0.760317
# 1107         Hh           0  1.718776
# 1123         Hh           0  0.760317
# 1133         Hh           0  0.760317
# 1137         Hh           0  0.760317
# 1148         Hh           0  0.760317
# 1154         Hh           0  0.037596
# 1196         Hh           0  0.760317
# 1229         Hh           0  0.760317
# 1234         Hh           0  0.029887
# 1238         Hh           0  0.760317
# 1254         Hh           0  0.760317
# 1261         Hh           0  0.937551
# 1267         Hh           0  0.300091
# 1289         Hh           0  0.937551
# 1295         Hh           0  0.088571
# 1303         Hh           0  0.760317
# 1315         Hh           0  0.743084
# 1366         Hh           0  0.760317
# 1367         Hh           0  0.760317
# 1379         Hh           0  0.048753
# 1382         Hh           0  0.937551
# 1385         Hh           0  0.760317
# 1394         Hh           0  0.046485
# 1402         Hh           0  0.760317
# 1415         Hh           0  0.212018
# 1426         Hh           0  0.056054
# 1439         Hh           0  0.760317
# 1463         Hh           0  0.072018
# 1488         Hh           0  0.042902
# 1500         Hh           0  0.029887
# 2006         Hh           0  0.086984
# 2044         Hh           0  0.026893
# 2045         Hh           0  0.760317

# %% [markdown]
# Viewing all the files that are have "Hh" in my instrument column.

# %%
hh_sum = df.loc[df['Instrument'].str.contains('Hh', case=False), 'Instrument'].count()
hh_sum
# Out:
# 50

# %% [markdown]
# Getting the count of of the "Hh"(meaning Hi-hat) instruments to see how many of these we would potentially be dropping and to decide if the audio files are worth looking through to classify one by one. Since it is 50, I have decided to drop all the rows with the "Hh" being the unclassified Hi-hats.

# %%
df = df[df['Instrument'].str.contains('Hh', case=False) == False]

# %% [markdown]
# Assigning the dataframe accordingly with the rows dropped.

# %%
df.shape
# Out:
# (2018, 5)

# %% [markdown]
# Verfiying rows dropped correctly.

# %%
Instrument = {
    'Kick': 0,
    '808': 1,
    'Snare': 2,
    'Open Hat': 3,
    'Closed Hat': 4,
}

indexed_instruments = {instrument: index for index, instrument in enumerate(Instrument)}

df['Index'] = df['Instrument'].map(indexed_instruments)

# %% [markdown]
# To later use particular instruments, I may need to index into them. By assigning them to diffrent numerical values, I will be able to get the information of particular audio files easier.

# %%
df.head(200)
# Out:
#                                              File_path  \
# 0    /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1    /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2    /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3    /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4    /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
# ..                                                 ...
# 195    /content/drive/MyDrive/Drums/closedhat_0041.wav
# 196      /content/drive/MyDrive/Drums/openhat_0051.wav
# 197    /content/drive/MyDrive/Drums/closedhat_0055.wav
# 198    /content/drive/MyDrive/Drums/closedhat_0135.wav
# 199         /content/drive/MyDrive/Drums/kick_0294.wav
#
#                                              File_name  Instrument  \
# 0    Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...       Snare
# 1    Snare 41 (Roy Ayers - The Old One Two (Move To...       Snare
# 2    Snare 42 (Roy Ayers - No Question (Album Versi...       Snare
# 3               Kick 37 (Roy Ayers - Can't You See Me)        Kick
# 4               Kick 38 (Roy Ayers - Can't You See Me)        Kick
# ..                                                 ...         ...
# 195                                     closedhat_0041  Closed Hat
# 196                                       openhat_0051    Open Hat
# 197                                     closedhat_0055  Closed Hat
# 198                                     closedhat_0135  Closed Hat
# 199                                          kick_0294        Kick
#
#      Start_time  End_time
# 0             0  0.100136
# 1             0  0.154694
# 2             0  0.189342
# 3             0  0.417596
# 4             0  0.258730
# ..          ...       ...
# 195           0  2.000000
# 196           0  1.283628
# 197           0  0.336190
# 198           0  0.512290
# 199           0  0.289977
#
# [200 rows x 5 columns]

# %% [markdown]
# Dataframe with the Index column.

# %%
non_zero_count = len(df[df['Start_time'] != 0])

if non_zero_count > 0:
    print(f"There are {non_zero_count} rows with non-zero values in the 'Start_time' column.")
else:
    print("All values in the 'Start_time' column are 0.")
# Out:
# All values in the 'Start_time' column are 0.

# %% [markdown]
# I am checking for all the columns now for abnormalities, including, start_time.

# %%
null_indices = df[df['Index'].isnull()].index.tolist()[1]

null_rows = df.loc[null_indices]
null_rows
# Out:
# File_path     /content/drive/MyDrive/Drums/OPEN-HAT (35).wav
# File_name                                      OPEN-HAT (35)
# Instrument                                          Open hat
# Start_time                                                 0
# End_time                                            1.075918
# Index                                                    NaN
# Name: 1019, dtype: object

# %% [markdown]
# Getting the rows with null values in my Index column.

# %%
print(df[df.isna().any(axis=1)])
# Out:
#                                            File_path      File_name  \
# 1016  /content/drive/MyDrive/Drums/OPEN-HAT (33).wav  OPEN-HAT (33)
# 1019  /content/drive/MyDrive/Drums/OPEN-HAT (35).wav  OPEN-HAT (35)
# 1022   /content/drive/MyDrive/Drums/OPEN-HAT (1).wav   OPEN-HAT (1)
# 1050   /content/drive/MyDrive/Drums/OPEN-HAT (8).wav   OPEN-HAT (8)
# 1051  /content/drive/MyDrive/Drums/OPEN-HAT (30).wav  OPEN-HAT (30)
# 1055  /content/drive/MyDrive/Drums/OPEN-HAT (37).wav  OPEN-HAT (37)
# 1090  /content/drive/MyDrive/Drums/OPEN-HAT (39).wav  OPEN-HAT (39)
# 1096  /content/drive/MyDrive/Drums/OPEN-HAT (29).wav  OPEN-HAT (29)
# 1099  /content/drive/MyDrive/Drums/OPEN-HAT (40).wav  OPEN-HAT (40)
# 1112  /content/drive/MyDrive/Drums/OPEN-HAT (48).wav  OPEN-HAT (48)
# 1125  /content/drive/MyDrive/Drums/OPEN-HAT (46).wav  OPEN-HAT (46)
# 1129  /content/drive/MyDrive/Drums/OPEN-HAT (47).wav  OPEN-HAT (47)
# 1130  /content/drive/MyDrive/Drums/OPEN-HAT (44).wav  OPEN-HAT (44)
# 1151  /content/drive/MyDrive/Drums/OPEN-HAT (51).wav  OPEN-HAT (51)
# 1157  /content/drive/MyDrive/Drums/OPEN-HAT (36).wav  OPEN-HAT (36)
# 1170  /content/drive/MyDrive/Drums/OPEN-HAT (41).wav  OPEN-HAT (41)
# 1183  /content/drive/MyDrive/Drums/OPEN-HAT (26).wav  OPEN-HAT (26)
# 1202  /content/drive/MyDrive/Drums/OPEN-HAT (27).wav  OPEN-HAT (27)
# 1207  /content/drive/MyDrive/Drums/OPEN-HAT (56).wav  OPEN-HAT (56)
# 1226   /content/drive/MyDrive/Drums/OPEN-HAT (5).wav   OPEN-HAT (5)
# 1233  /content/drive/MyDrive/Drums/OPEN-HAT (23).wav  OPEN-HAT (23)
# 1237  /content/drive/MyDrive/Drums/OPEN-HAT (28).wav  OPEN-HAT (28)
# 1244  /content/drive/MyDrive/Drums/OPEN-HAT (52).wav  OPEN-HAT (52)
# 1273  /content/drive/MyDrive/Drums/OPEN-HAT (20).wav  OPEN-HAT (20)
# 1276  /content/drive/MyDrive/Drums/OPEN-HAT (22).wav  OPEN-HAT (22)
# 1280  /content/drive/MyDrive/Drums/OPEN-HAT (14).wav  OPEN-HAT (14)
# 1288  /content/drive/MyDrive/Drums/OPEN-HAT (49).wav  OPEN-HAT (49)
# 1293  /content/drive/MyDrive/Drums/OPEN-HAT (54).wav  OPEN-HAT (54)
# 1301   /content/drive/MyDrive/Drums/OPEN-HAT (6).wav   OPEN-HAT (6)
# 1311  /content/drive/MyDrive/Drums/OPEN-HAT (45).wav  OPEN-HAT (45)
# 1318  /content/drive/MyDrive/Drums/OPEN-HAT (32).wav  OPEN-HAT (32)
# 1319   /content/drive/MyDrive/Drums/OPEN-HAT (9).wav   OPEN-HAT (9)
# 1344  /content/drive/MyDrive/Drums/OPEN-HAT (34).wav  OPEN-HAT (34)
# 1381  /content/drive/MyDrive/Drums/OPEN-HAT (53).wav  OPEN-HAT (53)
# 1383   /content/drive/MyDrive/Drums/OPEN-HAT (3).wav   OPEN-HAT (3)
# 1384   /content/drive/MyDrive/Drums/OPEN-HAT (7).wav   OPEN-HAT (7)
# 1393  /content/drive/MyDrive/Drums/OPEN-HAT (55).wav  OPEN-HAT (55)
# 1397   /content/drive/MyDrive/Drums/OPEN-HAT (2).wav   OPEN-HAT (2)
# 1405  /content/drive/MyDrive/Drums/OPEN-HAT (12).wav  OPEN-HAT (12)
# 1409  /content/drive/MyDrive/Drums/OPEN-HAT (50).wav  OPEN-HAT (50)
# 1413  /content/drive/MyDrive/Drums/OPEN-HAT (15).wav  OPEN-HAT (15)
# 1418  /content/drive/MyDrive/Drums/OPEN-HAT (16).wav  OPEN-HAT (16)
# 1424  /content/drive/MyDrive/Drums/OPEN-HAT (17).wav  OPEN-HAT (17)
# 1437  /content/drive/MyDrive/Drums/OPEN-HAT (43).wav  OPEN-HAT (43)
# 1462  /content/drive/MyDrive/Drums/OPEN-HAT (11).wav  OPEN-HAT (11)
# 1481  /content/drive/MyDrive/Drums/OPEN-HAT (38).wav  OPEN-HAT (38)
# 1486   /content/drive/MyDrive/Drums/OPEN-HAT (4).wav   OPEN-HAT (4)
# 1489  /content/drive/MyDrive/Drums/OPEN-HAT (13).wav  OPEN-HAT (13)
# 1508  /content/drive/MyDrive/Drums/OPEN-HAT (42).wav  OPEN-HAT (42)
# 1510  /content/drive/MyDrive/Drums/OPEN-HAT (10).wav  OPEN-HAT (10)
# 2005  /content/drive/MyDrive/Drums/OPEN-HAT (18).wav  OPEN-HAT (18)
# 2010  /content/drive/MyDrive/Drums/OPEN-HAT (25).wav  OPEN-HAT (25)
# 2021  /content/drive/MyDrive/Drums/OPEN-HAT (19).wav  OPEN-HAT (19)
# 2039  /content/drive/MyDrive/Drums/OPEN-HAT (21).wav  OPEN-HAT (21)
# 2053  /content/drive/MyDrive/Drums/OPEN-HAT (24).wav  OPEN-HAT (24)
# 2057  /content/drive/MyDrive/Drums/OPEN-HAT (31).wav  OPEN-HAT (31)
#
#      Instrument  Start_time  End_time  Index
# 1016   Open hat           0  1.507846    NaN
# 1019   Open hat           0  1.075918    NaN
# 1022   Open hat           0  0.544218    NaN
# 1050   Open hat           0  1.732154    NaN
# 1051   Open hat           0  1.507846    NaN
# 1055   Open hat           0  0.230794    NaN
# 1090   Open hat           0  2.000000    NaN
# 1096   Open hat           0  0.187528    NaN
# 1099   Open hat           0  0.187528    NaN
# 1112   Open hat           0  0.156281    NaN
# 1125   Open hat           0  0.214286    NaN
# 1129   Open hat           0  1.013424    NaN
# 1130   Open hat           0  2.470839    NaN
# 1151   Open hat           0  0.300000    NaN
# 1157   Open hat           0  4.071429    NaN
# 1170   Open hat           0  0.833152    NaN
# 1183   Open hat           0  0.433061    NaN
# 1202   Open hat           0  0.321451    NaN
# 1207   Open hat           0  0.597279    NaN
# 1226   Open hat           0  0.268844    NaN
# 1233   Open hat           0  0.107483    NaN
# 1237   Open hat           0  0.125034    NaN
# 1244   Open hat           0  0.400000    NaN
# 1273   Open hat           0  0.650567    NaN
# 1276   Open hat           0  0.437506    NaN
# 1280   Open hat           0  0.267029    NaN
# 1288   Open hat           0  0.500000    NaN
# 1293   Open hat           0  0.500000    NaN
# 1301   Open hat           0  1.960136    NaN
# 1311   Open hat           0  4.071429    NaN
# 1318   Open hat           0  1.507846    NaN
# 1319   Open hat           0  0.670023    NaN
# 1344   Open hat           0  1.507846    NaN
# 1381   Open hat           0  0.500000    NaN
# 1383   Open hat           0  0.845034    NaN
# 1384   Open hat           0  0.914286    NaN
# 1393   Open hat           0  0.400000    NaN
# 1397   Open hat           0  1.000000    NaN
# 1405   Open hat           0  0.754966    NaN
# 1409   Open hat           0  0.350023    NaN
# 1413   Open hat           0  0.767256    NaN
# 1418   Open hat           0  0.793651    NaN
# 1424   Open hat           0  0.205488    NaN
# 1437   Open hat           0  0.294649    NaN
# 1462   Open hat           0  0.743039    NaN
# 1481   Open hat           0  1.709841    NaN
# 1486   Open hat           0  0.323946    NaN
# 1489   Open hat           0  0.207438    NaN
# 1508   Open hat           0  0.203129    NaN
# 1510   Open hat           0  1.486077    NaN
# 2005   Open hat           0  0.107166    NaN
# 2010   Open hat           0  0.428571    NaN
# 2021   Open hat           0  0.062902    NaN
# 2039   Open hat           0  0.651020    NaN
# 2053   Open hat           0  0.125034    NaN
# 2057   Open hat           0  1.507846    NaN

# %% [markdown]
# There is many null values for the index column because the Open hat was not assigned as "Open Hat".

# %%
unique_instruments = df['Instrument'].unique()
print(f"Unique instruments: {unique_instruments}")
# Out:
# Unique instruments: ['Snare' 'Kick' 'Open Hat' '808' 'Closed Hat' 'Open hat']

# %%
df.loc[df['Instrument'] == 'Open hat', 'Index'] = df.loc[df['Instrument'] == 'Open hat', 'Index'].fillna(4.0)

# %%
df['Instrument'] = df['Instrument'].replace('Open hat', 'Open Hat')

# %% [markdown]
# Replacing all the Open hats to be labeled as Open Hat and labeled them with their assigned Index number.

# %%
print(df[df.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [File_path, File_name, Instrument, Start_time, End_time, Index]
# Index: []

# %%
num_instruments = df['Instrument'].nunique()
print(f"Number of unique instruments: {num_instruments}")
# Out:
# Number of unique instruments: 5

# %%
unique_instruments = df['Instrument'].unique()
print(f"Unique instruments: {unique_instruments}")
# Out:
# Unique instruments: ['Snare' 'Kick' 'Open Hat' '808' 'Closed Hat']

# %% [markdown]
# Changes merged the "opens hats" successfully.

# %%
df.head(5)
# Out:
#                                            File_path  \
# 0  /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1  /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2  /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3  /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4  /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
#
#                                            File_name Instrument  Start_time  \
# 0  Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...      Snare           0
# 1  Snare 41 (Roy Ayers - The Old One Two (Move To...      Snare           0
# 2  Snare 42 (Roy Ayers - No Question (Album Versi...      Snare           0
# 3             Kick 37 (Roy Ayers - Can't You See Me)       Kick           0
# 4             Kick 38 (Roy Ayers - Can't You See Me)       Kick           0
#
#    End_time
# 0  0.100136
# 1  0.154694
# 2  0.189342
# 3  0.417596
# 4  0.258730

# %%
df['Index'] = df['Index'].astype(int)

# %%
index_counts = df['Index'].value_counts()
index_counts
# Out:
# Index
# 0    530
# 1    481
# 2    435
# 4    302
# 3    270
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2018, 6)

# %% [markdown]
# From this, we can tell that all the Index rows, count-wise, were assigned correctly as the total amounts to 2018.

# %%
nan_counts = df.isnull().sum()
nan_counts
# Out:
# File_path     0
# File_name     0
# Instrument    0
# Start_time    0
# End_time      0
# Index         0
# dtype: int64

# %%
df.head(100)
# Out:
#                                             File_path  \
# 0   /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1   /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2   /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3   /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4   /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
# ..                                                ...
# 95  /content/drive/MyDrive/Drums/Kick 58 (Vern Bla...
# 96  /content/drive/MyDrive/Drums/Kick 59 (Area - G...
# 97  /content/drive/MyDrive/Drums/Snare 80 (Banco D...
# 98  /content/drive/MyDrive/Drums/Snare 81 (Banco D...
# 99  /content/drive/MyDrive/Drums/Snare 82 (Penny G...
#
#                                             File_name Instrument  Start_time  \
# 0   Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...      Snare           0
# 1   Snare 41 (Roy Ayers - The Old One Two (Move To...      Snare           0
# 2   Snare 42 (Roy Ayers - No Question (Album Versi...      Snare           0
# 3              Kick 37 (Roy Ayers - Can't You See Me)       Kick           0
# 4              Kick 38 (Roy Ayers - Can't You See Me)       Kick           0
# ..                                                ...        ...         ...
# 95           Kick 58 (Vern Blair Debate - Super Funk)       Kick           0
# 96  Kick 59 (Area - Guardati dal mese vicino all'a...       Kick           0
# 97  Snare 80 (Banco Del Mutuo Soccorso - Interno C...      Snare           0
# 98  Snare 81 (Banco Del Mutuo Soccorso - Interno C...      Snare           0
# 99     Snare 82 (Penny Goodwin - Too Soon You're Old)      Snare           0
#
#     End_time
# 0   0.100136
# 1   0.154694
# 2   0.189342
# 3   0.417596
# 4   0.258730
# ..       ...
# 95  0.219229
# 96  0.244807
# 97  0.162313
# 98  0.519546
# 99  0.390113
#
# [100 rows x 5 columns]

# %%
instrument_counts = df.groupby('Instrument').size()
print(f"Number of samples for each instrument:\n{instrument_counts}")
# Out:
# Number of samples for each instrument:
# Instrument
# 808           481
# Closed Hat    246
# Kick          530
# Open Hat      326
# Snare         435
# dtype: int64

# %% [markdown]
# Halfway through I decided that I wanted two ways to ensure that I would not run into any issues in the modeling process so I deicded to encode the Instrument column. This would be depedent on whther I approach the model as a classifcation model or CNN(Convolutional Neural Network). As of now I am most imntrested in applying the CNN model. This would do the same thing the index column does however, it seperate its assigned numbers into diffrent columns.

# %%
instruments = df['Instrument'].unique()
num_classes = len(instruments)

instrument_to_index = {instrument: i for i, instrument in enumerate(instruments)}

df['Instrument_encoded'] = df['Instrument'].map(instrument_to_index)
one_hot_encoded = to_categorical(df['Instrument_encoded'], num_classes=num_classes)

for i in range(num_classes):
    df[f'Instrument_{i}'] = one_hot_encoded[:, i]

# %%
df.head(5)
# Out:
#                                            File_path  \
# 0  /content/drive/MyDrive/Drums/Snare 40 (Roy Aye...
# 1  /content/drive/MyDrive/Drums/Snare 41 (Roy Aye...
# 2  /content/drive/MyDrive/Drums/Snare 42 (Roy Aye...
# 3  /content/drive/MyDrive/Drums/Kick 37 (Roy Ayer...
# 4  /content/drive/MyDrive/Drums/Kick 38 (Roy Ayer...
#
#                                            File_name Instrument  Start_time  \
# 0  Snare 40 (Roy Ayers - Ebony Blaze (Album Versi...      Snare           0
# 1  Snare 41 (Roy Ayers - The Old One Two (Move To...      Snare           0
# 2  Snare 42 (Roy Ayers - No Question (Album Versi...      Snare           0
# 3             Kick 37 (Roy Ayers - Can't You See Me)       Kick           0
# 4             Kick 38 (Roy Ayers - Can't You See Me)       Kick           0
#
#    End_time
# 0  0.100136
# 1  0.154694
# 2  0.189342
# 3  0.417596
# 4  0.258730

# %%
df.to_csv('/content/drive/MyDrive/Instrument_classifier.csv', index=False)

# %% [markdown]
# Saved the dataframe as a CSV, ready to be used for the EDA process and further modeling.

# %% [markdown]
# To summarize, my goal is to create a instrument classifier that can predict what instrument it is. This would work with 5 instruments which include Kick, Snare, Closed Hat, Open Hat, and 808. I am using real audio data and extracted this data to make a dataframe and in this process I cleaned certain discrepancys such as null values in columns, duplicates, incorrect labeling, and more. I decided to choose these particular columns as features as I belive these are columns that could potenitally best help identify the instrument. In the EDA and modeling process I may discover other features that I may want to feature engineer however, this is what i have so far. Lastly, I decided to encode my instrument column as I beleive that may be the foundation of my model.

# %% [markdown]
# End of Data/Cleaning notebook.
